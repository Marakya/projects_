# %% [markdown]
# ### Соревнование на Kaggle "Предсказание степени загрезненности воды"

# %% [markdown]
# Score (Kaggle) - 0.83836

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.image as img
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import matplotlib as mpl
from scipy import stats
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Загружаем данные

# %%
train = pd.read_csv('Train.csv', delimiter = ',', index_col = 'idx')
train.head(3)
# Out:
#               code  year            period        id Country    tourists  \
# idx
# 11   EEA_3161-03-3  2009  2009-04--2009-10  FRGR0220  France  71176346.0
# 20   EEA_3161-05-5  2009  2009-01--2009-12   FRDR179  France  71176346.0
# 27   EEA_3161-01-1  2009  2009-01--2009-12   FRDR174  France  71176346.0
#
#      venue  rate  food  glass  metal  other  paper  plastic  leather  \
# idx
# 11     0.0   0.0  32.0   10.0    3.0   26.0   20.0      9.0      0.0
# 20     3.0   0.0  32.0   10.0    3.0   26.0   20.0      9.0      0.0
# 27     3.0   0.0  32.0   10.0    3.0   26.0   20.0      9.0      0.0
#
#      green_waste  waste_recycling
# idx
# 11           0.0            22.26
# 20           0.0            22.26
# 27           0.0            22.26

# %%
test = pd.read_csv('Test.csv', delimiter = ',', index_col = 'idx')
test.head(3)
# Out:
#                code  year            period          id         Country  \
# idx
# 19    EEA_3161-01-1  2009  2009-01--2009-12     FRDR179          France
# 46   EEA_31615-01-7  2009  2009-01--2009-12   FRGR0004B          France
# 94    EEA_3161-02-2  2007  2007-01--2007-12  UKSC023165  United Kingdom
#
#        tourists  venue  rate  food  glass  metal  other  paper  plastic  \
# idx
# 19   71176346.0    3.0   0.0  32.0   10.0    3.0   26.0   20.0      9.0
# 46   71176346.0    2.0   0.0  32.0   10.0    3.0   26.0   20.0      9.0
# 94   25867961.0    0.0   0.0  16.7    2.2    3.5   28.2   18.9     20.2
#
#      leather  green_waste  waste_recycling
# idx
# 19       0.0          0.0            22.26
# 46       0.0          0.0            22.26
# 94       0.0          2.7            27.25

# %%
target = pd.read_csv('Target.csv', delimiter = ',', index_col = 'idx')
target.head(3)
# Out:
#      polution_clf
# idx
# 11              0
# 20              0
# 27              0

# %%
submission = pd.read_csv("Submission.csv")
submission
# Out:
#        idx  polution_clf
# 0       19             0
# 1       46             0
# 2       94             0
# 3       96             0
# 4       98             0
# ..     ...           ...
# 727  19780             0
# 728  19824             0
# 729  19856             0
# 730  19882             0
# 731  19915             0
#
# [732 rows x 2 columns]

# %%
df = pd.concat([train, test])

# %%
df = df.join(target, on='idx')

# %%
df
# Out:
#                  code  year            period                  id  \
# idx
# 11      EEA_3161-03-3  2009  2009-04--2009-10            FRGR0220
# 20      EEA_3161-05-5  2009  2009-01--2009-12             FRDR179
# 27      EEA_3161-01-1  2009  2009-01--2009-12             FRDR174
# 28      EEA_3161-05-5  2009  2009-01--2009-12             FRDR174
# 33      EEA_3161-03-3  2009  2009-01--2009-12            FRGR0173
# ...               ...   ...               ...                 ...
# 19780  EEA_31615-01-7  2010  2010-01--2010-12  ES020MSPF000000395
# 19824   EEA_3161-02-2  2009  2009-01--2009-12            FRFR289B
# 19856   EEA_3161-01-1  2009  2009-01--2009-12           FRDR2007E
# 19882  EEA_31615-01-7  2009  2009-01--2009-12          UKSC006828
# 19915   EEA_3161-02-2  2009  2009-01--2009-12      ES080MSPF18-28
#
#               Country    tourists  venue       rate  food  glass  metal  \
# idx
# 11             France  71176346.0    0.0   0.000000  32.0   10.0    3.0
# 20             France  71176346.0    3.0   0.000000  32.0   10.0    3.0
# 27             France  71176346.0    3.0   0.000000  32.0   10.0    3.0
# 28             France  71176346.0    3.0   0.000000  32.0   10.0    3.0
# 33             France  71176346.0    0.0   0.000000  32.0   10.0    3.0
# ...               ...         ...    ...        ...   ...    ...    ...
# 19780           Spain  50941692.0    0.0  87.158924  49.0    8.0    3.0
# 19824          France  71176346.0    0.0   0.000000  32.0   10.0    3.0
# 19856          France  71176346.0    0.0   0.000000  32.0   10.0    3.0
# 19882  United Kingdom  25867961.0    0.0   0.000000  16.7    2.2    3.5
# 19915           Spain  50941692.0    0.0  87.158924  49.0    8.0    3.0
#
#        other  paper  plastic  leather  green_waste  waste_recycling  \
# idx
# 11      26.0   20.0      9.0      0.0          0.0            22.26
# 20      26.0   20.0      9.0      0.0          0.0            22.26
# 27      26.0   20.0      9.0      0.0          0.0            22.26
# 28      26.0   20.0      9.0      0.0          0.0            22.26
# 33      26.0   20.0      9.0      0.0          0.0            22.26
# ...      ...    ...      ...      ...          ...              ...
# 19780   14.0   15.0      9.0      0.0          0.0            16.84
# 19824   26.0   20.0      9.0      0.0          0.0            22.26
# 19856   26.0   20.0      9.0      0.0          0.0            22.26
# 19882   28.2   18.9     20.2      0.0          2.7            27.25
# 19915   14.0   15.0      9.0      0.0          0.0            16.84
#
#        polution_clf
# idx
# 11              0.0
# 20              0.0
# 27              0.0
# 28              1.0
# 33              0.0
# ...             ...
# 19780           NaN
# 19824           NaN
# 19856           NaN
# 19882           NaN
# 19915           NaN
#
# [3660 rows x 18 columns]

# %% [markdown]
# ### Разведывательный анализ данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3660 entries, 11 to 19915
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code             3660 non-null   object
#  1   year             3660 non-null   int64
#  2   period           3660 non-null   object
#  3   id               3660 non-null   object
#  4   Country          3660 non-null   object
#  5   tourists         3660 non-null   float64
#  6   venue            3660 non-null   float64
#  7   rate             3660 non-null   float64
#  8   food             3660 non-null   float64
#  9   glass            3660 non-null   float64
#  10  metal            3660 non-null   float64
#  11  other            3660 non-null   float64
#  12  paper            3660 non-null   float64
#  13  plastic          3660 non-null   float64
#  14  leather          3660 non-null   float64
#  15  green_waste      3660 non-null   float64
#  16  waste_recycling  3660 non-null   float64
#  17  polution_clf     2928 non-null   float64
# dtypes: float64(13), int64(1), object(4)
# memory usage: 543.3+ KB

# %% [markdown]
# Пропущенных и нулевых значений нет

# %%
df.describe()
# Out:
#               year      tourists        venue         rate         food  \
# count  3660.000000  3.660000e+03  3660.000000  3660.000000  3660.000000
# mean   2008.656831  5.569954e+07     0.090984    11.070253    31.853109
# std       0.937363  2.304268e+07     0.561277    28.400648     8.886749
# min    2005.000000  5.300380e+05     0.000000     0.000000    14.180000
# 25%    2008.000000  5.094169e+07     0.000000     0.000000    32.000000
# 50%    2009.000000  7.117635e+07     0.000000     0.000000    32.000000
# 75%    2009.000000  7.117635e+07     0.000000     0.000000    32.000000
# max    2017.000000  7.117635e+07     7.000000    87.158924    62.300000
#
#              glass        metal        other        paper      plastic  \
# count  3660.000000  3660.000000  3660.000000  3660.000000  3660.000000
# mean      8.529104     3.086691    24.146068    19.697694    10.506295
# std       2.974285     0.883262     6.262395     4.261491     4.215245
# min       2.200000     1.380000     0.000000     6.100000     1.450000
# 25%       8.000000     3.000000    26.000000    18.900000     9.000000
# 50%      10.000000     3.000000    26.000000    20.000000     9.000000
# 75%      10.000000     3.000000    26.000000    20.000000     9.000000
# max      21.400000     9.200000    44.050000    37.830000    22.900000
#
#            leather  green_waste  waste_recycling  polution_clf
# count  3660.000000  3660.000000      3660.000000   2928.000000
# mean      0.094820     0.833948        23.062085      0.505123
# std       0.582198     2.556819         4.803606      0.500059
# min       0.000000     0.000000         0.760000      0.000000
# 25%       0.000000     0.000000        22.260000      0.000000
# 50%       0.000000     0.000000        22.260000      1.000000
# 75%       0.000000     0.000000        22.260000      1.000000
# max       4.000000    19.180000        47.830000      1.000000

# %% [markdown]
# #### Числовые и категориальные признаки

# %%
cat_column = ["code", "period", "id", "Country"]
num_column = ["year", "tourists", "venue", "rate", "food", "glass", "metal", "other", "paper", "plastic", "leather", "green_waste", "waste_recycling", "polution_clf"]

# %% [markdown]
# ### Анализ числовых признаков

# %%
df_num = df[num_column]

# %%
df_num.hist(figsize=(16, 16), bins=20, grid=False);

# %% [markdown]
# Видно, что столбец polution_clf (таргет) равномерно разбит между двумя классами, где 0 - незагрезненно, 1 - загрезненно

# %% [markdown]
# ### Рассмотрим корреляцию между числовыми признаками

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.2)
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #### Видно, что таргет polution имеет больший коэффициент корреляции со следующими признаками:
# other rate - возьмем эти столбцы

# %% [markdown]
# Удалим остальные столбцы

# %%
df = df.drop(columns = ["green_waste","metal","leather","glass","plastic", "venue", "year", "paper"], axis = 1)

# %%
df = df.drop("tourists", axis = 1)

# %%
df = df.drop("food", axis = 1)
df = df.drop("waste_recycling", axis = 1)

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.2)
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #### Рассмотрим связь признаков друг с другом и с таргетом

# %% [markdown]
# #### Связь other с таргетом

# %%
grid = sns.jointplot(df["polution_clf"], df["other"], kind='reg')
grid.fig.set_figwidth(5)
grid.fig.set_figheight(5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 grid = sns.jointplot(df["polution_clf"], df["other"], kind='reg')
#       2 grid.fig.set_figwidth(5)
#       3 grid.fig.set_figheight(5)
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# #### Связь rate с таргетом

# %%
grid = sns.jointplot(df["polution_clf"], df["rate"], kind='reg')
grid.fig.set_figwidth(5)
grid.fig.set_figheight(5)
plt.show()

# %% [markdown]
# Наблюдается слабая корреляция между этими признаками и таргетом, однако она есть

# %% [markdown]
# #### Связь other с rate

# %%
grid = sns.jointplot(df["other"], df["rate"], kind='reg')
grid.fig.set_figwidth(5)
grid.fig.set_figheight(5)
plt.show()

# %% [markdown]
# Видно, что между other и rate наблюдается сильная отрицательная корреляция

# %% [markdown]
# ### Сделаем one hot encoding категориальных признаков

# %%
df.head(3)
# Out:
#               code            period        id Country  rate  other  \
# idx
# 11   EEA_3161-03-3  2009-04--2009-10  FRGR0220  France   0.0   26.0
# 20   EEA_3161-05-5  2009-01--2009-12   FRDR179  France   0.0   26.0
# 27   EEA_3161-01-1  2009-01--2009-12   FRDR174  France   0.0   26.0
#
#      polution_clf
# idx
# 11            0.0
# 20            0.0
# 27            0.0

# %%
df.drop("polution_clf", axis=1, inplace=True)

# %%
df = pd.get_dummies(df, columns=["code", "id", "period", "Country"])

# %%
num_column = ["rate", "other"]

# %% [markdown]
# ### MinMaxScaler для числовых признаков

# %%
def get_scale(df,col, model):
    
    scal = model.fit_transform(df[col])
    df[col] = scal
    return df

# %%
df = get_scale(df, num_column, MinMaxScaler())

# %%
X_train
# Out:
# array([[0.        , 0.59023837, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.59023837, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.59023837, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.31782066, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.59023837, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.31782066, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# #### Разбиваем обратно на тестовую и тренировочную выборки

# %%
train = df.iloc[0:train.shape[0],:]
test = df.iloc[train.shape[0]:,:]

# %%
y_train = target['polution_clf'].values.ravel()

# %%
X_train = train.values
X_test = test.values

# %%
from sklearn.model_selection import train_test_split
X_train_, X_val, y_train_, y_val = train_test_split(X_train,y_train,test_size = 0.2, random_state = 42)

# %% [markdown]
# #### Воспользуемся логистической регрессией из sklearn

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0).fit(X_train_, y_train_)

# %% [markdown]
# #### Качество модели на тренировочном и тестовом датасете

# %%
print(f'Test Score = {clf.score(X_val, y_val):.2f}, Train Score = {clf.score(X_train_, y_train_):.2f}')
# Out:
# Test Score = 0.80, Train Score = 0.87

# %% [markdown]
# На тестовой выборке происходит падение скора, применим регуляризацию

# %%
list1 = [9.6, 9.7, 9.8, 9.9, 10.0, 10.1, 10.2, 10.3, 10.4, 10.5]
for c in list1:
    clf = LogisticRegression(penalty='l2', solver='lbfgs', max_iter=1000, tol=000.1, C=c)
    clf.fit(X_train_, y_train_)
    print(f'{c}:')
    print(f'Test Score = {clf.score(X_val, y_val):.5f}, Train Score = {clf.score(X_train_, y_train_):.5f}')
    print('-'*50)
# Out:
# 9.6:
# Test Score = 0.85495, Train Score = 0.98121
# --------------------------------------------------
# 9.7:
# Test Score = 0.85666, Train Score = 0.98121
# --------------------------------------------------
# 9.8:
# Test Score = 0.85666, Train Score = 0.98164
# --------------------------------------------------
# 9.9:
# Test Score = 0.85666, Train Score = 0.98164
# --------------------------------------------------
# 10.0:
# Test Score = 0.85666, Train Score = 0.98164
# --------------------------------------------------
# 10.1:
# Test Score = 0.85666, Train Score = 0.98164
# --------------------------------------------------
# 10.2:
# Test Score = 0.85495, Train Score = 0.98164
# --------------------------------------------------
# 10.3:
# Test Score = 0.84983, Train Score = 0.98164
# --------------------------------------------------
# 10.4:
# Test Score = 0.84983, Train Score = 0.98164
# --------------------------------------------------
# 10.5:
# Test Score = 0.84983, Train Score = 0.98164
# --------------------------------------------------

# %% [markdown]
# Вывод: наилучшее значение: 10.0

# %% [markdown]
# Обучим модель на всей тренировочной выборке

# %%
clf = LogisticRegression(penalty='l2', solver='lbfgs', max_iter=1000, tol=000.1, C=10.0).fit(X_train, y_train)

# %% [markdown]
# #### Сделаем предсказание и занесем его в submission

# %%
y_pred = clf.predict(X_test)

# %%
submission['polution_clf'] = y_pred

# %%
submission = submission.set_index('idx')

# %%
submission
# Out:
#        polution_clf
# idx
# 19                0
# 46                1
# 94                1
# 96                1
# 98                1
# ...             ...
# 19780             1
# 19824             1
# 19856             0
# 19882             0
# 19915             0
#
# [732 rows x 1 columns]

# %%
submission.to_csv('My_Submission_no_all_K.csv',index=True)
